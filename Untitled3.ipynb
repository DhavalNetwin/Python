# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'E:\Dhaval\Elastic Search\Python\E-Book\Data File\Corrplot\Maindata.csv')
FinaltransformData = pd.read_csv(r'E:\Dhaval\Elastic Search\Python\E-Book\Data File\Corrplot\transFormdata.csv')

# %%
plt.scatter(data.I_w_BHL_Weg,data.I_w_BHR_Weg)

# %%
plt.scatter(FinaltransformData.I_w_BHL_Weg,FinaltransformData.I_w_BHR_Weg)
