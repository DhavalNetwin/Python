# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data[0]['title']
# Out:
# ' BUG-22796 Concat multicolumn tz-aware DataFrame'

# %%
import pandas as pd

# %%
issues = pd.DataFrame(data, columns=['number','title','labels','state'])

# %%
issues
# Out:
#     number                                              title  \
# 0    23036    BUG-22796 Concat multicolumn tz-aware DataFrame
# 1    23035                          memory leak in MiltiIndex
# 2    23034  By convention, tuples indicate multi-level loo...
# 3    23033  Problem with nlargest / nsmallest on dataframe...
# 4    23032  Add cookbook entry for triangular correlation ...
# 5    23031            BUG: Fix PeriodIndex +/- TimedeltaIndex
# 6    23030  mssql pandas.DataFrame.to_sql AttributeError: ...
# 7    23028  __finalize__ consistency DataFrame vs SparseDa...
# 8    23026                Block.copy `deep` kwarg consistency
# 9    23025  [WIP] Accepts integer/float string with units ...
# 10   23024       DOC: Upgraded Docstring pandas.DataFrame.dot
# 11   23023                       Block.shape inconsistencies?
# 12   23022                            WIP: Fuse all the types
# 13   23020               BUG: merging on an Integer EA raises
# 14   23019  PERF: only output an html id if a style is app...
# 15   23018                         CLN: internal import rules
# 16   23017           Make DataFrame.dtypes return Categorical
# 17   23015  Cannot create python environment due to broken...
# 18   23014  DOC: improve documentation of DateOffset (clos...
# 19   23013  BUG: Interval should disallow Interval/Period ...
# 20   23011                Disable .str-accessor for byte data
# 21   23010      BUG: millis res on parsed DatetimeIndex slice
# 22   23009                                  sets in str.cat?!
# 23   23008  API: Expose groupby API for fast custom calcul...
# 24   23007  BUG: Don't include array-like repr in plot tit...
# 25   23006                      openpyxl depreciation warning
# 26   23004  CLN GH22875 Replace bare excepts by explicit e...
# 27   23002                      rolling with string variables
# 28   23001                     CI: Fix yaml/yml inconsistency
# 29   22999                            iloc bug / memory error
#
#                                                labels state
# 0   [{'id': 13098779, 'node_id': 'MDU6TGFiZWwxMzA5...  open
# 1                                                  []  open
# 2                                                  []  open
# 3                                                  []  open
# 4                                                  []  open
# 5   [{'id': 60635328, 'node_id': 'MDU6TGFiZWw2MDYz...  open
# 6                                                  []  open
# 7                                                  []  open
# 8                                                  []  open
# 9   [{'id': 42670965, 'node_id': 'MDU6TGFiZWw0MjY3...  open
# 10  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 11                                                 []  open
# 12  [{'id': 49094459, 'node_id': 'MDU6TGFiZWw0OTA5...  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 57395487, 'node_id': 'MDU6TGFiZWw1NzM5...  open
# 15                                                 []  open
# 16                                                 []  open
# 17                                                 []  open
# 18  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 19  [{'id': 150096370, 'node_id': 'MDU6TGFiZWwxNTA...  open
# 20                                                 []  open
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 22                                                 []  open
# 23                                                 []  open
# 24  [{'id': 2413328, 'node_id': 'MDU6TGFiZWwyNDEzM...  open
# 25                                                 []  open
# 26  [{'id': 42670965, 'node_id': 'MDU6TGFiZWw0MjY3...  open
# 27  [{'id': 195647922, 'node_id': 'MDU6TGFiZWwxOTU...  open
# 28  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 29                                                 []  open
