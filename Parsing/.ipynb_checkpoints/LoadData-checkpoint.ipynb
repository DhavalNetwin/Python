# %%
def ReadCSVData(path):
    import pandas as pd
    return pd.read_csv(path)

# %%
ReadCSVData('E:\Dhaval\Elastic Search\Python\E-Book\Data File\highstoragesystem-data-for-energy-optimization\HRSS_normal_optimized.csv')
# Out:
#        Timestamp  Labels  I_w_BLO_Weg  O_w_BLO_power  O_w_BLO_voltage  \
# 0       0.000000       0            7              0                0
# 1       0.043999       0            7              0                0
# 2       0.099998       0            7              0                0
# 3       0.143997       0            7              0                0
# 4       0.249001       0            7              0                0
# 5       0.292999       0            7              0                0
# 6       0.350998       0            7              0                0
# 7       0.394997       0            7              0                0
# 8       0.496002       0            7              0                0
# 9       0.542000       0            7              0                0
# 10      0.598999       0            7              0                0
# 11      0.642998       0            7              0                0
# ...
